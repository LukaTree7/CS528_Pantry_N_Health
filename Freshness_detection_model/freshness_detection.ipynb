# %%
# !pip install tensorflow tensorflow-hub tensorflow-datasets pillow numpy matplotlib

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.11/dist-packages (0.16.1)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-hub) (2.18.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.21.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-datasets) (25.3.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.70.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Mounted at /content/drive

# %%
import os

print("Training Images :")
dataset_Train_path = "/content/drive/MyDrive/dataset_fresh/Train"

for category in ["fresh", "rotten"]:
    folder_path = os.path.join(dataset_Train_path, category)
    print(f"{category}: {len(os.listdir(folder_path))} images")

print("Training Images :")

dataset_Test_path = "/content/drive/MyDrive/dataset_fresh/Test"

for category in ["fresh", "rotten"]:
    folder_path = os.path.join(dataset_Test_path, category)
    print(f"{category}: {len(os.listdir(folder_path))} images")
# Out:
# Training Images :
# fresh: 11210 images
# rotten: 12419 images
# Training Images :
# fresh: 3245 images
# rotten: 3493 images

# %%
# Restructuring the data
import shutil


base_dir = "/content/drive/MyDrive/dataset_fresh"
train_dir = os.path.join(base_dir, "Train")
test_dir = os.path.join(base_dir, "Test")


new_structure = {
    "train": {"fresh": [], "rotten": []},
    "test": {"fresh": [], "rotten": []}
}


def move_files(src_folder, dst_folder):
    if not os.path.exists(dst_folder):
        os.makedirs(dst_folder)
    for filename in os.listdir(src_folder):
        src_path = os.path.join(src_folder, filename)
        dst_path = os.path.join(dst_folder, filename)
        if os.path.isfile(src_path):
            shutil.move(src_path, dst_path)


for phase in ["train", "test"]:
    phase_dir = train_dir if phase == "train" else test_dir

    for category in os.listdir(phase_dir):
        category_path = os.path.join(phase_dir, category)


        if "fresh" in category.lower():
            new_category = "fresh"
        elif "rotten" in category.lower():
            new_category = "rotten"
        else:
            continue


        new_path = os.path.join(phase_dir, new_category)
        move_files(category_path, new_path)


        if os.path.exists(category_path) and not os.listdir(category_path):
            os.rmdir(category_path)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score

dataset_path = "/content/drive/MyDrive/dataset_fresh" # Change as per your file path
train_path = os.path.join(dataset_path, "Train")
test_path = os.path.join(dataset_path, "Test")

batch_size = 32
img_size = (224, 224)  # default input size

train_data = tf.keras.preprocessing.image_dataset_from_directory(
    train_path,
    image_size=img_size,
    batch_size=batch_size,
    shuffle=True
)

test_data = tf.keras.preprocessing.image_dataset_from_directory(
    test_path,
    image_size=img_size,
    batch_size=batch_size,
    shuffle=False
)

class_names = train_data.class_names
print("Classes:", class_names)

normalization_layer = tf.keras.layers.Rescaling(1./255)
train_data = train_data.map(lambda x, y: (normalization_layer(x), y))
test_data = test_data.map(lambda x, y: (normalization_layer(x), y))

base_model = keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)
base_model.trainable = False

model = keras.Sequential([
    base_model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(2, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

epochs = 10
history = model.fit(train_data,validation_data=test_data,epochs=epochs)

print("\nEvaluating model on test data...")

test_loss, test_acc = model.evaluate(test_data)
print(f"\nTest Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")


test_preds = []
test_labels = []
for x, y in test_data:
    test_preds.extend(model.predict(x, verbose=0))
    test_labels.extend(y.numpy())

test_pred_classes = np.argmax(test_preds, axis=1)
test_labels = np.array(test_labels)

precision = precision_score(test_labels, test_pred_classes)
recall = recall_score(test_labels, test_pred_classes)
f1 = f1_score(test_labels, test_pred_classes)

print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test F1 Score: {f1:.4f}")

print("\nClassification Report:")
print(classification_report(test_labels, test_pred_classes, target_names=class_names))

print("\nConfusion Matrix:")
print(confusion_matrix(test_labels, test_pred_classes))


plt.figure(figsize=(14, 5))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.tight_layout()
plt.show()

# Model to TensorFlow Lite for android Intergration
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()


tflite_model_path = "/content/drive/MyDrive/mobilenet_freshness.tflite"
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)

print("✅ Model saved at:", tflite_model_path)
# Out:
# Found 23629 files belonging to 2 classes.
# Found 6738 files belonging to 2 classes.
# Classes: ['fresh', 'rotten']
# Epoch 1/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1481s 2s/step - accuracy: 0.9150 - loss: 0.2025 - val_accuracy: 0.9746 - val_loss: 0.0753
# Epoch 2/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1312s 2s/step - accuracy: 0.9764 - loss: 0.0658 - val_accuracy: 0.9828 - val_loss: 0.0492
# Epoch 3/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1344s 2s/step - accuracy: 0.9832 - loss: 0.0456 - val_accuracy: 0.9825 - val_loss: 0.0476
# Epoch 4/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1352s 2s/step - accuracy: 0.9841 - loss: 0.0392 - val_accuracy: 0.9868 - val_loss: 0.0394
# Epoch 5/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1352s 2s/step - accuracy: 0.9872 - loss: 0.0343 - val_accuracy: 0.9908 - val_loss: 0.0274
# Epoch 6/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1353s 2s/step - accuracy: 0.9905 - loss: 0.0259 - val_accuracy: 0.9927 - val_loss: 0.0205
# Epoch 7/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1396s 2s/step - accuracy: 0.9923 - loss: 0.0219 - val_accuracy: 0.9918 - val_loss: 0.0261
# Epoch 8/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1338s 2s/step - accuracy: 0.9917 - loss: 0.0228 - val_accuracy: 0.9915 - val_loss: 0.0225
# Epoch 9/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1348s 2s/step - accuracy: 0.9920 - loss: 0.0251 - val_accuracy: 0.9944 - val_loss: 0.0219
# Epoch 10/10
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1378s 2s/step - accuracy: 0.9923 - loss: 0.0189 - val_accuracy: 0.9938 - val_loss: 0.0199
#
# Evaluating model on test data...
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.9941 - loss: 0.0196
#
# Test Accuracy: 0.9938
# Test Loss: 0.0199
# Test Precision: 0.9920
# Test Recall: 0.9960
# Test F1 Score: 0.9940
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        fresh       1.00      0.99      0.99      3245
#       rotten       0.99      1.00      0.99      3493
#
#     accuracy                           0.99      6738
#    macro avg       0.99      0.99      0.99      6738
# weighted avg       0.99      0.99      0.99      6738
#
#
# Confusion Matrix:
# [[3217   28]
#  [  14 3479]]
# Saved artifact at '/tmp/tmpua0yv_98'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_314')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   136195411481360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411479056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123342864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411481168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411480592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123345936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123340176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123346320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123345552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123346704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123341328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123340944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123340560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123340752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123344016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123339408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123339024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123338640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123344592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123347088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123337296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123344400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123336720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123337104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195123339792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363258832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363260176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363260560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363260368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363259024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363261712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363262096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363262480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363262288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363259600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411485008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411485392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411485584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411485968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411487504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411487312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363259408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363263632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195411486736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363264016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363264976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363265360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363265744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363265552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363261328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363266896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363267280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363267664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363267472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363260944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363268816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363269200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363269584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363269392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363264592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363270736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363271120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363271504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363271312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363266512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363272656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363273040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363273424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363273232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363268432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363274576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363270352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118940816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363274192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363272272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118941968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118942352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118942736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118942544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118941200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118943888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118944272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118944656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118944464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118940240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118946192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118948112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118947152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118946000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118949072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118949456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118949648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118947536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118943504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118951568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118951376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118946768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118950608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118952336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118952144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118945808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118953488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118953872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118954256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118954064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118940432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118955408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118955024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118953104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118955984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118948496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195118954640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363374288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363373328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363374096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363373136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363375824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363376208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363376592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363376400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363373520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363377744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363378128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363378512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363378320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363374672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363379664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363380048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363380432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363380240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363375440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363381584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363381968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363382352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363382160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363377360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363383504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363383888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363384272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363384080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363379280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363385424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363385808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363386192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363386000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363381200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363387344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363387728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363388112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363387920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363383120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363389264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363385040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363242064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363388880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363386960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363243792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363244176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363244560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363244368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363243024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363245712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363246096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363246480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363246288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363242448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363247632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363248016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363248400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363248208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363243408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363249552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363249936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363250320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363250128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363245328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363251472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363251856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363252240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363252048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363247248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363253392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363253776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363254160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363253968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363249168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363255312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363255696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363256080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363255888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363251088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363257232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363256848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363254928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363257808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363253008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195363256464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124167888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124166928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124167696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124166736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124169424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124169808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124170192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124170000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124167120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124171344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124171728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124172112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124171920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124168272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124173264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124173648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124174032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124173840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124169040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124175184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124175568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124175952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124175760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124170960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124177104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124177488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124177872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124177680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124172880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124179024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124179408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124179792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124179600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124174800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124180944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124181328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124181712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124181520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124176720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124182864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124178640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388424272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124182480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195124180560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388426000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388426768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388426576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388428304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388428688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388428496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388424656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388429840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388430224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388430416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388425616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388424464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388432912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136195388433680: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Model saved at: /content/drive/MyDrive/mobilenet_freshness.tflite

# %%
model_path = "/content/drive/MyDrive/mobilenet_freshness.tflite"
